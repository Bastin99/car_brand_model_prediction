# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
classifier=Sequential()
classifier.add(Convolution2D(32,(3,3),input_shape=(64,64,3),activation='relu'))

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
classifier.add(Flatten())

# %%
classifier.add(Dense(128,activation='relu'))
classifier.add(Dense(41,activation='softmax'))
classifier.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)

# %%
train_set = train_datagen.flow_from_directory(
        '/content/car_dataset/Train_images',
        target_size=(64,64),
        batch_size=100,
        class_mode='categorical',subset='training')
# Out:
# Found 51588 images belonging to 41 classes.

# %%
test_set = train_datagen.flow_from_directory(
        '/content/car_dataset/Train_images',
        target_size=(64, 64),
         batch_size=100,
        class_mode='categorical',subset='validation')
# Out:
# Found 12879 images belonging to 41 classes.

# %%
classifier.fit(
        train_set,
        epochs=25,
        validation_data=test_set)
# Out:
# Epoch 1/25
# 516/516 [==============================] - 291s 562ms/step - loss: 3.3771 - accuracy: 0.1014 - val_loss: 3.3594 - val_accuracy: 0.0860
# Epoch 2/25
# 516/516 [==============================] - 287s 556ms/step - loss: 3.2137 - accuracy: 0.1314 - val_loss: 3.3312 - val_accuracy: 0.0956
# Epoch 3/25
# 516/516 [==============================] - 287s 556ms/step - loss: 3.1176 - accuracy: 0.1538 - val_loss: 3.3165 - val_accuracy: 0.1027
# Epoch 4/25
# 516/516 [==============================] - 288s 558ms/step - loss: 3.0451 - accuracy: 0.1724 - val_loss: 3.3294 - val_accuracy: 0.1099
# Epoch 5/25
# 516/516 [==============================] - 286s 555ms/step - loss: 2.9879 - accuracy: 0.1870 - val_loss: 3.3288 - val_accuracy: 0.1056
# Epoch 6/25
# 516/516 [==============================] - 290s 562ms/step - loss: 2.9354 - accuracy: 0.2016 - val_loss: 3.3404 - val_accuracy: 0.1075
# Epoch 7/25
# 516/516 [==============================] - 290s 561ms/step - loss: 2.8940 - accuracy: 0.2130 - val_loss: 3.3374 - val_accuracy: 0.1116
# Epoch 8/25
# 516/516 [==============================] - 287s 556ms/step - loss: 2.8567 - accuracy: 0.2217 - val_loss: 3.3297 - val_accuracy: 0.1123
# Epoch 9/25
# 516/516 [==============================] - 284s 551ms/step - loss: 2.8178 - accuracy: 0.2317 - val_loss: 3.3535 - val_accuracy: 0.1113
# Epoch 10/25
# 516/516 [==============================] - 284s 551ms/step - loss: 2.7826 - accuracy: 0.2410 - val_loss: 3.3789 - val_accuracy: 0.1141
# Epoch 11/25
# 516/516 [==============================] - 284s 550ms/step - loss: 2.7494 - accuracy: 0.2508 - val_loss: 3.3765 - val_accuracy: 0.1172
# Epoch 12/25
# 516/516 [==============================] - 283s 549ms/step - loss: 2.7191 - accuracy: 0.2604 - val_loss: 3.4066 - val_accuracy: 0.1200
# Epoch 13/25
# 516/516 [==============================] - 283s 549ms/step - loss: 2.6956 - accuracy: 0.2671 - val_loss: 3.3904 - val_accuracy: 0.1187
# Epoch 14/25
# 516/516 [==============================] - 283s 549ms/step - loss: 2.6676 - accuracy: 0.2748 - val_loss: 3.4245 - val_accuracy: 0.1160
# Epoch 15/25
# 516/516 [==============================] - 283s 548ms/step - loss: 2.6439 - accuracy: 0.2802 - val_loss: 3.4218 - val_accuracy: 0.1172
